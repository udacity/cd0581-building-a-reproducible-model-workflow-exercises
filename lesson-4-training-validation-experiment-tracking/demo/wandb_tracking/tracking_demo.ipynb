# %%
import wandb
import matplotlib.pyplot as plt
import numpy as np

# %%
run = wandb.init(project="tracking_demo")
# Out:
# wandb: Currently logged in as: giacomovianello (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.10.29 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.24<br/>
#                 Syncing run <strong style="color:#cdcd00">still-brook-8</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/giacomovianello/tracking_demo" target="_blank">https://wandb.ai/giacomovianello/tracking_demo</a><br/>
#                 Run page: <a href="https://wandb.ai/giacomovianello/tracking_demo/runs/196erloz" target="_blank">https://wandb.ai/giacomovianello/tracking_demo/runs/196erloz</a><br/>
#                 Run data is saved locally in <code>/home/giacomov/udacity/repo/nd0821-c2-build-model-workflow/lesson-4-training-validation-experiment-tracking/demo/wandb_tracking/wandb/run-20210506_010443-196erloz</code><br/><br/>

# %%
# Storing hyper parameters
run.config.update({
    "batch_size": 128,
    "weight_decay": 0.01,
    "augmentations": {
        "rot_angle": 45,
        "crop_size": 224
    }
})

# NOTE: if we have arguments to argparse, we can do:
# parser = argparse.ArgumentParser(description="Train a Random Forest")
# parser.add_argument("--batch_size", type=int, ...)
# parser.add_argument("--weight_decay", type=float, ...)
# args = parser.parse_arguments()
# run.config.update(args)

# %%
# Log a final score
run.summary['accuracy'] = 0.9

# %%
# Log a time-varying metric
# The last value will also be reported in the table, unless
# we override it with run.summary['loss']
for i in range(10):
    run.log(
        {
            "loss": 1.2 - i * 0.1
        }
    )

# %%
# Log multiple time-varying metrics
for i in range(10):
    run.log(
        {
            "recall": 0.8 + i * 0.01,
            "ROC": 0.1 + i**2 * 0.01
        }
    )

# %%
# Explicit x-axis
for i in range(10):
    run.log(
        {
            "precision": 0.8 + i * 0.01,
            "epoch": i
        }
    )

# %%
from numpy import sqrt 

# Credits: Trae Blain (https://gist.github.com/traeblain/1487795)
x1 = np.arange(-7.25, 7.25, 0.012)
y1 = np.arange(-5, 5, 0.012)
x, y = np.meshgrid(x1, y1)

eq1 = ((x/7)**2*sqrt(abs(abs(x)-3)/(abs(x)-3))+(y/3)**2*sqrt(abs(y+3/7*sqrt(33))/(y+3/7*sqrt(33)))-1)
eq2 = (abs(x/2)-((3*sqrt(33)-7)/112)*x**2-3+sqrt(1-(abs(abs(x)-2)-1)**2)-y)
eq3 = (9*sqrt(abs((abs(x)-1)*(abs(x)-.75))/((1-abs(x))*(abs(x)-.75)))-8*abs(x)-y)
eq4 = (3*abs(x)+.75*sqrt(abs((abs(x)-.75)*(abs(x)-.5))/((.75-abs(x))*(abs(x)-.5)))-y)
eq5 = (2.25*sqrt(abs((x-.5)*(x+.5))/((.5-x)*(.5+x)))-y)
eq6 = (6*sqrt(10)/7+(1.5-.5*abs(x))*sqrt(abs(abs(x)-1)/(abs(x)-1))-(6*sqrt(10)/14)*sqrt(4-(abs(x)-1)**2)-y)
equation=[eq1,eq2,eq3,eq4,eq5,eq6]

fig, sub = plt.subplots()
for f in equation:
    sub.contour(x, y, f, [0])
# Out:
# <ipython-input-8-c91ea0469688>:8: RuntimeWarning: invalid value encountered in sqrt
#   eq1 = ((x/7)**2*sqrt(abs(abs(x)-3)/(abs(x)-3))+(y/3)**2*sqrt(abs(y+3/7*sqrt(33))/(y+3/7*sqrt(33)))-1)
# <ipython-input-8-c91ea0469688>:9: RuntimeWarning: invalid value encountered in sqrt
#   eq2 = (abs(x/2)-((3*sqrt(33)-7)/112)*x**2-3+sqrt(1-(abs(abs(x)-2)-1)**2)-y)
# <ipython-input-8-c91ea0469688>:10: RuntimeWarning: invalid value encountered in sqrt
#   eq3 = (9*sqrt(abs((abs(x)-1)*(abs(x)-.75))/((1-abs(x))*(abs(x)-.75)))-8*abs(x)-y)
# <ipython-input-8-c91ea0469688>:11: RuntimeWarning: invalid value encountered in sqrt
#   eq4 = (3*abs(x)+.75*sqrt(abs((abs(x)-.75)*(abs(x)-.5))/((.75-abs(x))*(abs(x)-.5)))-y)
# <ipython-input-8-c91ea0469688>:12: RuntimeWarning: invalid value encountered in sqrt
#   eq5 = (2.25*sqrt(abs((x-.5)*(x+.5))/((.5-x)*(.5+x)))-y)
# <ipython-input-8-c91ea0469688>:13: RuntimeWarning: invalid value encountered in sqrt
#   eq6 = (6*sqrt(10)/7+(1.5-.5*abs(x))*sqrt(abs(abs(x)-1)/(abs(x)-1))-(6*sqrt(10)/14)*sqrt(4-(abs(x)-1)**2)-y)

# %%
run.log({
    "batman": wandb.Image(fig)
})

# %%
run.finish()
# Out:
# <br/>Waiting for W&B process to finish, PID 27903<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.02MB of 0.02MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/giacomov/udacity/repo/nd0821-c2-build-model-workflow/lesson-4-training-validation-experiment-tracking/demo/wandb_tracking/wandb/run-20210506_010443-196erloz/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/giacomov/udacity/repo/nd0821-c2-build-model-workflow/lesson-4-training-validation-experiment-tracking/demo/wandb_tracking/wandb/run-20210506_010443-196erloz/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>accuracy</td><td>0.9</td></tr><tr><td>loss</td><td>0.3</td></tr><tr><td>_runtime</td><td>9</td></tr><tr><td>_timestamp</td><td>1620288292</td></tr><tr><td>_step</td><td>30</td></tr><tr><td>recall</td><td>0.89</td></tr><tr><td>ROC</td><td>0.91</td></tr><tr><td>precision</td><td>0.89</td></tr><tr><td>epoch</td><td>9</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>loss</td><td>█▇▆▆▅▄▃▃▂▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▂▂▃▃▃▃▃▃▃▃▃▃█</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▂▂▃▃▃▃▃▃▃▃▃▃█</td></tr><tr><td>_step</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>recall</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>ROC</td><td>▁▁▁▂▂▃▄▅▇█</td></tr><tr><td>precision</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/>
# Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">still-brook-8</strong>: <a href="https://wandb.ai/giacomovianello/tracking_demo/runs/196erloz" target="_blank">https://wandb.ai/giacomovianello/tracking_demo/runs/196erloz</a><br/>
